# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("../../data/processed/processed_day_ahead_prices.csv", decimal=",")
df.reset_index(inplace=True)

# %%
df.tail()
# Out:
#        index  hour        date  price
# 17851  17851    19  2024-07-12  96.62
# 17852  17852    20  2024-07-12  91.05
# 17853  17853    21  2024-07-12  92.34
# 17854  17854    22  2024-07-12  42.08
# 17855  17855    23  2024-07-12  26.48

# %%
# We se a couple of spikles in price in this date interval. A quick look online at hourly
# temperatures in southern Sweden at these dates shows some extremely low temperatures roughly
# around the spikes. This supports the idea that temperature data is a good predictor of
# electricity prices. We shall see during the modelling evaluation phase if this is true.
sns.lineplot(data=df[df["date"].between("2023-12-22", "2024-01-18")], x="index", y="price")
# Out:
# <Axes: xlabel='index', ylabel='price'>

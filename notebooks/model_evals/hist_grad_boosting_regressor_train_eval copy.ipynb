# %%
import sys
sys.path.append("../../")
from sklearn.ensemble import HistGradientBoostingRegressor
from src.utils.lagged_price_features.time_series_split_eval import (
    get_sorted_split_dirs,
    train_plot_preds_from_split_dir,
    calculate_mape,
    plot_mape_for_split_indices,
)

# %%
model = HistGradientBoostingRegressor()
split_dirs = get_sorted_split_dirs("../../data/lagged_price_features/time_series_split")

# %%
train_plot_preds_from_split_dir(model=model, split_dir=split_dirs[0])

# %%
mape = calculate_mape(model=model, split_dirs=split_dirs)
mape
# Out:
# Evaluating split ../../data/lagged_price_features/time_series_split/0
# Evaluating split ../../data/lagged_price_features/time_series_split/1
# Evaluating split ../../data/lagged_price_features/time_series_split/2
# Evaluating split ../../data/lagged_price_features/time_series_split/3
# Evaluating split ../../data/lagged_price_features/time_series_split/4
# Evaluating split ../../data/lagged_price_features/time_series_split/5
# Evaluating split ../../data/lagged_price_features/time_series_split/6
# Evaluating split ../../data/lagged_price_features/time_series_split/7
# Evaluating split ../../data/lagged_price_features/time_series_split/8
# Evaluating split ../../data/lagged_price_features/time_series_split/9
# Evaluating split ../../data/lagged_price_features/time_series_split/10
# Evaluating split ../../data/lagged_price_features/time_series_split/11
# Evaluating split ../../data/lagged_price_features/time_series_split/12
# Evaluating split ../../data/lagged_price_features/time_series_split/13
# Evaluating split ../../data/lagged_price_features/time_series_split/14
# Evaluating split ../../data/lagged_price_features/time_series_split/15
# Evaluating split ../../data/lagged_price_features/time_series_split/16
# Evaluating split ../../data/lagged_price_features/time_series_split/17
# Evaluating split ../../data/lagged_price_features/time_series_split/18
# Evaluating split ../../data/lagged_price_features/time_series_split/19
# Evaluating split ../../data/lagged_price_features/time_series_split/20
# Evaluating split ../../data/lagged_price_features/time_series_split/21
# Evaluating split ../../data/lagged_price_features/time_series_split/22
# Evaluating split ../../data/lagged_price_features/time_series_split/23
# [np.float64(1022668659427572.0),
#  np.float64(4.743058987248569),
#  np.float64(0.7055718001164047),
#  np.float64(990726645141686.6),
#  np.float64(4.0460263698659285),
#  np.float64(6.463903969030589),
#  np.float64(2.358075138139705),
#  np.float64(8.75799770052099),
#  np.float64(0.6327897033450531),
#  np.float64(0.9127478112365118),
#  np.float64(2774443349114429.0),
#  np.float64(0.2942088852894394),
#  np.float64(1.4274301533321954),
#  np.float64(6729418111577184.0),
#  np.float64(3.8836807272527314),
#  np.float64(0.3154734294006772),
#  np.float64(124.16251975076686),
#  np.float64(1.3648467644600778e+16),
#  np.float64(0.3910929457882135),
#  np.float64(5009925052599176.0),
#  np.float64(198.3763332377292),
#  np.float64(46.17560621580922),
#  np.float64(0.6849499955738478),
#  np.float64(0.4612918294473616)]

# %%
plot_mape_for_split_indices(split_dirs, mape)
